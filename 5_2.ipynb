# %% [markdown]
# <a href="https://colab.research.google.com/github/yeho99/STATISTICS/blob/main/5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 라이브러리 로드

# %%
# 데이터 분석을 위한 pandas 라이브러리를 불러옵니다.
# 데이터 시각화를 위한 seaborn 을 불러옵니다.
import pandas as pd
import seaborn as sns

# %%
print(pd.__version__)
print(sns.__version__)
# Out:
# 2.2.2
# 0.13.2

# %%
# 0.11.0 버전에서 변화가 많으니 이 버전 이상을 사용해 주세요.
# !pip install seaborn --upgrade

# %% [markdown]
# ## 데이터셋 불러오기
# <img src="https://pandas.pydata.org/docs/_images/02_io_readwrite.svg">
#
# * seaborn 데이터셋 위치 : https://github.com/mwaskom/seaborn-data

# %%
# df
df=sns.load_dataset("mpg")
df. shape
# Out:
# (398, 9)

# %% [markdown]
# ## 데이터셋 일부만 가져오기

# %%
# head
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
# tail
df.tail(3)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin           name
# 395          82    usa  dodge rampage
# 396          82    usa    ford ranger
# 397          82    usa     chevy s-10

# %%
# sample
df.sample(3)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 368  27.0          4         112.0        88.0    2640          18.6
# 212  16.5          8         350.0       180.0    4380          12.1
# 214  13.0          8         302.0       130.0    3870          15.0
#
#      model_year origin                      name
# 368          82    usa  chevrolet cavalier wagon
# 212          76    usa          cadillac seville
# 214          76    usa                 ford f108

# %% [markdown]
# ## 매번 봐야 하는 기술통계값 코드 한 줄로 보기
# ### Pandas Profiling
# * [pandas-profiling/pandas-profiling: Create HTML profiling reports from pandas DataFrame objects](https://github.com/pandas-profiling/pandas-profiling)

# %%
# 아래 명령어로 설치합니다.
# !pip install ydata_profiling --upgrade

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Ydata Profiling Report")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# 주피터 노트북이 있는 위치에 html파일이 생성됩니다.
profile.to_file("ydata_profile_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### sweetviz
# * [sweetviz · PyPI](https://pypi.org/project/sweetviz/)
# <img src="https://warehouse-camo.ingress.cmh1.psfhosted.org/210c4eb7317c8b0d2e7d0784b1a9697c096050ef/687474703a2f2f636f6f6c74696d696e672e636f6d2f53562f4c61796f75742d416e696d332e676966">

# %%
# 아래 명령어로 설치해 주셔야지 사용할 수 있습니다.
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 75.6 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv

my_report = sv.analyze(df)
# 타겟변수 없이 그릴 수도 있고 타겟변수를 지정할 수도 있습니다.
# 타겟변수는 범주형이 아닌 수치, bool 값만 가능합니다.
# 데이터에 따라 수치형으로 되어있지만 동작하지 않을 수도 있습니다.
# my_report = sv.analyze(df, target_feat ='mpg')
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1295621496.py in <cell line: 0>()
#       1 import sweetviz as sv
#       2
# ----> 3 my_report = sv.analyze(df)
#       4 # 타겟변수 없이 그릴 수도 있고 타겟변수를 지정할 수도 있습니다.
#       5 # 타겟변수는 범주형이 아닌 수치, bool 값만 가능합니다.
#
# /usr/local/lib/python3.12/dist-packages/sweetviz/sv_public.py in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# ...
